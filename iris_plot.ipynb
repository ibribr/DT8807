# %% [markdown]
# <a href="https://colab.research.google.com/github/ibribr/DT8807/blob/master/iris_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# load and visualize iris data set
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from sklearn import datasets

iris = datasets.load_iris()
x = iris.data#[:,:2]  # the first two features
y = iris.target

print(iris.feature_names)
print(iris.target_names)
label = ["setosa', 'versicolor', 'virginica']

plt.scatter(x[:,0], x[:,1], c=y, cmap=plt.cm.Set1, edgecolor="k", label=label)
plt.grid()
plt.xlabel("Sepal length")
plt.ylabel("sepal width")
plt.legend()
plt.show()
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# now upload a CSV file from your local drive - uplaod the file to Google Drive
import pandas as pd
path = '/content/drive/MyDrive/Dataset/iris.csv'
iris = pd.read_csv(path)
iris.head(5)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
iris['variety']= label_encoder.fit_transform(iris['variety'])

#df['variety'].unique()

iris.head(150)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
sns.set(style="ticks", color_codes=True)
print(iris.head())
sns.pairplot(iris, hue="variety", palette="husl", markers=["o", "s", "D"])
# Out:
#    sepal.length  sepal.width  petal.length  petal.width  variety
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0
